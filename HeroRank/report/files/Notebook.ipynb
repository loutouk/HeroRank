# %%
import re

# Using readlines() 
file1 = open('top200.tsv', 'r') 
file2 = open("out.txt", "a")
Lines = file1.readlines() 
  
count = 0
# Strips the newline character 
for line in Lines: 
    res = re.split('[ \t]', line)
    print(res)
    count = int(float(res[len(res)-1].rstrip()))
    for i in range(0, count):
        a = 1
        #file2.write(res[0] + " ")

file1.close()
file2.close()
# Out:
# ['SPIDER-MAN/PETER', 'PAR', '', '', '', '65.30145169185606\n']
# ['CAPTAIN', 'AMERICA', '63.88076158255209\n']
# ['IRON', 'MAN/TONY', 'STARK', '', '', '', '', '47.78439209820876\n']
# ['THOR/DR.', 'DONALD', 'BLAK', '', '', '', '41.10198842476511\n']
# ['HUMAN', 'TORCH/JOHNNY', 'S', '', '', '', '40.961893005714444\n']
# ['THING/BENJAMIN', 'J.', 'GR', '', '', '', '40.71591477779993\n']
# ['WOLVERINE/LOGAN', '', '', '', '', '40.36215763215303\n']
# ['MR.', 'FANTASTIC/REED', 'R', '', '', '', '39.097919064283765\n']
# ['INVISIBLE', 'WOMAN/SUE', '', '', '', '', '35.669240887520466\n']
# ['BEAST/HENRY', '&HANK&', 'P', '', '', '', '34.75903937891034\n']
# ['SCARLET', 'WITCH/WANDA', '', '', '', '', '34.61324112087041\n']
# ['STORM/ORORO', 'MUNROE', 'S', '', '', '', '34.01534742101286\n']
# ['CYCLOPS/SCOTT', 'SUMMER', '', '', '', '33.253037978630914\n']
# ['VISION', '', '33.233145708602706\n']
# ['HAWK', '', '', '', '30.999664584601753\n']
# ...
